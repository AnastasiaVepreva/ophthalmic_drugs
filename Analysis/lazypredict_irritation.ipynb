# %%
from lazypredict.Supervised import LazyClassifier
import numpy as np
import pandas as pd
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier

# %%
df = pd.read_csv(r'C:\Users\Anastasia\Documents\GitHub\ophthalmic_drugs\Analysis\irritation_MACCS.csv')
df
# Out:
#       exactmw    amw  lipinskiHBA  lipinskiHBD  NumRotatableBonds  NumHBD  \
# 0       54.05  54.09         0.00         0.00               0.00    0.00
# 1       56.06  56.11         0.00         0.00               1.00    0.00
# 2       58.01  58.04         2.00         0.00               1.00    0.00
# 3       58.04  58.08         1.00         0.00               1.00    0.00
# 4       59.02  59.04         1.00         0.00               0.00    0.00
# ...       ...    ...          ...          ...                ...     ...
# 5215   780.43 780.95        14.00         6.00               7.00    6.00
# 5216   780.43 780.95        14.00         6.00               7.00    6.00
# 5217   788.85 789.10        11.00         6.00               9.00    6.00
# 5218   790.87 791.12        11.00         7.00              11.00    7.00
# 5219   794.45 794.98        14.00         5.00               8.00    5.00
#
#       NumHBA  NumHeavyAtoms  NumAtoms  NumHeteroatoms  ...  chi1n  chi2n  \
# ...

# %%
x = np.array(df.iloc[0:5220, 1:43])
y = np.array(df[['Class']])

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
reg = LazyClassifier(verbose=0, 
                    ignore_warnings=False, 
                    custom_metric=None)
models, predictions = reg.fit(xtrain, xtest, ytrain, ytest)
models
# Out:
#  14%|█▍        | 4/29 [00:02<00:13,  1.82it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
#  90%|████████▉ | 26/29 [00:08<00:00,  3.27it/s]
# StackingClassifier model failed to execute
# StackingClassifier.__init__() missing 1 required positional argument: 'estimators'
# 100%|██████████| 29/29 [00:10<00:00,  2.86it/s]
# [LightGBM] [Info] Number of positive: 3103, number of negative: 1073
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5628
# [LightGBM] [Info] Number of data points in the train set: 4176, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.743056 -> initscore=1.061911
# [LightGBM] [Info] Start training from score 1.061911
# ...

# %%
clf = ExtraTreesClassifier(n_estimators=100, random_state=0)
clf.fit(xtrain, ytrain)
# Out:
# ExtraTreesClassifier(random_state=0)

# %%
clf.score(xtest, ytest)
# Out:
# 0.9262452107279694

# %%
clf.score(xtrain, ytrain)
# Out:
# 1.0

# %%
clf = GradientBoostingClassifier(random_state=50)
clf.fit(xtrain, ytrain)
# Out:
# GradientBoostingClassifier(random_state=50)

# %%
clf.score(xtrain, ytrain)
# Out:
# 0.9547413793103449

# %%
clf.score(xtest, ytest)
# Out:
# 0.9252873563218391
